# %%
import re 
import tweepy 
import numpy as np
from tweepy import OAuthHandler 
from textblob import TextBlob 
  
class TwitterClient(object): 
    ''' 
    Generic Twitter Class for sentiment analysis. 
    '''
    def __init__(self): 
        ''' 
        Class constructor or initialization method. 
        '''
        # keys and tokens from the Twitter Dev Console 
        consumer_key = 'xxxxxxxxxxxxxxxxxxxxxxxxxxx'
        consumer_secret = 'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx'
        access_token = 'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx'
        access_token_secret = 'xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx'
  
        # attempt authentication 
        try: 
            # create OAuthHandler object 
            self.auth = OAuthHandler(consumer_key, consumer_secret) 
            # set access token and secret 
            self.auth.set_access_token(access_token, access_token_secret) 
            # create tweepy API object to fetch tweets 
            self.api = tweepy.API(self.auth) 
        except: 
            print("Error: Authentication Failed") 
  
    def clean_tweet(self, tweet): 
        ''' 
        Utility function to clean tweet text by removing links, special characters 
        using simple regex statements. 
        '''
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())
  
    def get_tweet_sentiment(self, tweet): 
        ''' 
        Utility function to classify sentiment of passed tweet 
        using textblob's sentiment method 
        '''
        # create TextBlob object of passed tweet text 
        analysis = TextBlob(self.clean_tweet(tweet)) 
        # set sentiment 
        if analysis.sentiment.polarity > 0: 
            return 'positive'
        elif analysis.sentiment.polarity == 0: 
            return 'neutral'
        else: 
            return 'negative'
  
    def get_tweets(self, query, count = 10): 
        ''' 
        Main function to fetch tweets and parse them. 
        '''
        # empty list to store parsed tweets 
        tweets = [] 
  
        try: 
            # call twitter api to fetch tweets 
            fetched_tweets = self.api.search(q = query, count = count) 
  
            # parsing tweets one by one 
            for tweet in fetched_tweets: 
                # empty dictionary to store required params of a tweet 
                parsed_tweet = {} 
  
                # saving text of tweet 
                parsed_tweet['text'] = tweet.text 
                # saving sentiment of tweet 
                parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text) 
  
                # appending parsed tweet to tweets list 
                if tweet.retweet_count > 0: 
                    # if tweet has retweets, ensure that it is appended only once 
                    if parsed_tweet not in tweets: 
                        tweets.append(parsed_tweet) 
                else: 
                    tweets.append(parsed_tweet) 
  
            # return parsed tweets 
            return tweets 
  
        except tweepy.TweepError as e: 
            # print error (if any) 
            print("Error : " + str(e)) 
  
def main(): 
    # creating object of TwitterClient Class 
    api = TwitterClient() 
    # calling function to get tweets 
    tweets = api.get_tweets(query = 'Donald Trump', count = 200) 
  
    # picking positive tweets from tweets 
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive'] 
    # percentage of positive tweets 
    print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets))) 
    
    # picking negative tweets from tweets 
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative'] 
    # percentage of negative tweets 
    print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets))) 
    total = ntweets + ptweets
    
    def Diff(li1, li2): 
        li_dif = [i for i in li1 + li2 if i not in li1 or i not in li2] 
        return li_dif 

    li = Diff(tweets, total)

    # percentage of neutral tweets 
    print("Neutral tweets percentage: {} % ".format(100*len(li)/len(tweets)))

    # printing first 5 positive tweets 
    print("\n\nPositive tweets:") 
    for tweet in ptweets[:10]: 
        print(tweet['text']) 
  
    # printing first 5 negative tweets 
    print("\n\nNegative tweets:") 
    for tweet in ntweets[:10]: 
        print(tweet['text']) 
  
if __name__ == "__main__": 
    # calling main function 
    main()
# Out:
# Positive tweets percentage: 25.423728813559322 %
# Negative tweets percentage: 18.64406779661017 %
# Neutral tweets percentage: 55.932203389830505 %
#
#
# Positive tweets:
# @thespybrief Almost certainly bullshit since it involves Tom Arnold but here you go.
# https://t.co/yEcmZd6d9t
# RT @joncoopertweets: Soon-to-be-indicted bag of human garbage Donald Trump, Jr. posted a picture of a childish love letter, drawn in crayon…
# RT @TheDemCoalition: Soon-to-be-indicted bag of human garbage @DonaldJTrumpJr posted a picture of a childish love letter, drawn in crayon,…
# RT @ChrisCuomo: "My understanding is that Dr. Ford already passed a lie detector test, if Donald Trump was smart, and he's not, he would pu…
# RT @SenSanders: Donald Trump claims Democrats want to "destroy your Social Security.”
#
# Surprise! He's lying.
#
# His own economic advisor ju…
# @NateSilver538 Living in these times it is.. The Democracy of America is at stake right now and Donald Trump may be… https://t.co/P2LTRyO372
# RT @Hope012015: Donald Trump Jr mocks Kavanaugh sexual assault accusations with meme https://t.co/FQeztFha2f
# RT @ThomasPKennedy3: Now my fellow Patriots who joined me in supporting &amp; electing Donald J Trump our 45th President are now #DregsofSociet…
# RT @freedom_moates: Breaking News: I conspired against Democrats to elect Donald Trump. Retweet if you helped in this conspiracy.
# RT @ProudResister: The Republican party has now supported a sexual predator for the Presidency (Donald Trump), the Senate (Roy Moore) and t…
#
#
# Negative tweets:
# RT @AC360: "The idea I am kneeling in water to make it look deep is idiotic."
#
# @AndersonCooper debunks the lies being spread by Donald Tru…
# RT @KFILE: .@AndersonCooper on his show tonight responded to the false meme shared by senior HUD official Lynne Patton and Donald Trump Jr.…
# RT @The_UnSilent_: Never forget - Convicted sex offender Jeffrey Epstein pleaded the fifth when asked if Donald Trump socialized with minor…
# @krassenstein At Donald Trump Jr, your time will come, get ready for a very small room #pos
# RT @RJNewsflash: Donald Trump Jr. calls out Joe Biden for insulting Trump supporters.
#
# Do you think Biden went too far?
#
# https://t.co/SlkC7…
# RT @RevJJackson: Please READ, SHARE WIDELY RT &amp; LIKE @Suntimes, “By enforcing climate change denial, Trump puts us all in peril.”  https://…
# RT @xeni: As Kavanaugh is confronted with allegations of attempted rape, we are forced again to confront the fact that Donald Trump,  Presi…
# RT @PamelaUnplugged: I’ve spent the last two years learning to accept the fact that I’m “deplorable.”  And now, I learn it was all a lie an…
# RT @smalltownandrew: https://t.co/aeWi6e95Xa
#
# 💥Bombshell💥
#
#  Finally the truth will come out about the motives behind the Russian hoax and t…
# RT @147DW: Here is the WaPo article excerpt connecting that firm to Russia’s Prevezon &amp; Fusion GPS &amp; Magnitsky Act. Yup- the accuser’s brot…
